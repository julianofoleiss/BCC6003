# %%
from scipy.io import arff
import os
from glob import glob
import pandas as pd

# %%
arffs = sorted(glob("weka_dados/*.arff"))
csvs = [ "%s.csv" % os.path.basename(i).split(".")[0] for i in arffs]

# %%
data, meta = arff.loadarff(arffs[0])
pd.DataFrame(data)
# Out:
#          00     01      02    03    04      05     06     07     08     09  \
# 0     0.001  0.001   5.000  13.0   9.0   1.000  0.001  0.001  0.001  0.001
# 1     0.001  0.001   0.001  12.0  13.0   5.000  0.001  0.001  0.001  0.001
# 2     0.001  0.001   0.001   4.0  15.0  12.000  0.001  0.001  0.001  0.001
# 3     0.001  0.001   7.000  15.0  13.0   1.000  0.001  0.001  0.001  8.000
# 4     0.001  0.001   0.001   1.0  11.0   0.001  0.001  0.001  0.001  0.001
# ...     ...    ...     ...   ...   ...     ...    ...    ...    ...    ...
# 1792  0.001  0.001   4.000  10.0  13.0   6.000  0.001  0.001  0.001  1.000
# 1793  0.001  0.001   6.000  16.0  13.0  11.000  1.000  0.001  0.001  0.001
# 1794  0.001  0.001   1.000  11.0  15.0   1.000  0.001  0.001  0.001  0.001
# 1795  0.001  0.001   2.000  10.0   7.0   0.001  0.001  0.001  0.001  0.001
# 1796  0.001  0.001  10.000  14.0   8.0   1.000  0.001  0.001  0.001  2.000
#
# ...

# %%
for f in arffs:
    data, meta = arff.loadarff(f)
# Out:
# Dataset: TesteKnn
# 	00's type is numeric
# 	01's type is numeric
# 	02's type is numeric
# 	03's type is numeric
# 	04's type is numeric
# 	05's type is numeric
# 	06's type is numeric
# 	07's type is numeric
# 	08's type is numeric
# 	09's type is numeric
# 	10's type is numeric
# 	11's type is numeric
# 	12's type is numeric
# 	13's type is numeric
# 	14's type is numeric
# 	15's type is numeric
# 	16's type is numeric
# 	17's type is numeric
# 	18's type is numeric
# 	19's type is numeric
# 	20's type is numeric
# 	21's type is numeric
# 	22's type is numeric
# 	23's type is numeric
# 	24's type is numeric
# 	25's type is numeric
# 	26's type is numeric
# 	27's type is numeric
# 	28's type is numeric
# 	29's type is numeric
# 	30's type is numeric
# 	31's type is numeric
# 	32's type is numeric
# 	33's type is numeric
# 	34's type is numeric
# 	35's type is numeric
# 	36's type is numeric
# 	37's type is numeric
# 	38's type is numeric
# 	39's type is numeric
# ...
